# %% [markdown]
# ## Calculating the Return of Indices

# %% [markdown]
# Consider three famous American market indices – Dow Jones, S&P 500, and the Nasdaq for the period of 1st of January 2000 until today.

# %%
import numpy as np
import pandas as pd
import pandas_datareader.data as wb
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

tickers=['^GSPC', '^IXIC', '^DJI']

data=pd.DataFrame()

for i in tickers:
    data[i]=wb.DataReader(i, data_source='yahoo', start='2000-1-1')['Adj Close']

# %%
data.tail()
# Out:
#                   ^GSPC         ^IXIC          ^DJI
# Date
# 2020-06-16  3124.739990   9895.870117  26289.980469
# 2020-06-17  3113.489990   9910.530273  26119.609375
# 2020-06-18  3115.340088   9943.049805  26080.099609
# 2020-06-19  3097.739990   9946.120117  25871.460938
# 2020-06-22  3117.439941  10043.024414  26013.689453

# %%
data.plot()

# %% [markdown]
# Normalize the data to 100 and plot the results on a graph.

# %%
(data/data.iloc[0]*100).plot()

# %% [markdown]
# How would you explain the common and the different parts of the behavior of the three indices?

# %% [markdown]
# common-global market changes  diffrent- industry specific changes

# %% [markdown]
# Obtain the simple returns of the indices.

# %%
returns=(data/data.shift(1))-1
returns.tail()
# Out:
#                ^GSPC     ^IXIC      ^DJI
# Date
# 2020-06-16  0.018962  0.017464  0.020449
# 2020-06-17 -0.003600  0.001481 -0.006480
# 2020-06-18  0.000594  0.003281 -0.001513
# 2020-06-19 -0.005649  0.000309 -0.008000
# 2020-06-22  0.006359  0.009743  0.005498

# %% [markdown]
# Estimate the average annual return of each index.

# %%
(returns.mean())*250
# Out:
# ^GSPC    0.056785
# ^IXIC    0.075338
# ^DJI     0.058533
# dtype: float64
